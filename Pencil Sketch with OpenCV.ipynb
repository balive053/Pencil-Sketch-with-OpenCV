# %% [markdown]
# ## Creating pencil sketch from original image

# %% [markdown]
# ### Import and install necessary packages

# %%
#pip install opencv-python

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Image

# %%
img = cv2.imread('playful_dog2.jpg')
img = cv2.resize(img, (500, 500))

# %% [markdown]
# ### Create Pencil Sketch

# %%
# Create grayscale version
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Blur image
blurred_img = cv2.GaussianBlur(gray_img, (21,21), 0)

# Use grayscale and blurred image to create pencil sketch
pencil_sketch_img = cv2.divide(gray_img, blurred_img, scale=256)

# %% [markdown]
# ### Display Image

# %%
# Display images (note: does not display on GitHub)
cv2.imshow('Original image', img)
cv2.imshow('Gray image', pencil_sketch_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Additional inplace display - Original Image
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Additional inplace display - Pencil Sketch
pencil_sketch_img = cv2.cvtColor(pencil_sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(pencil_sketch_img)

# %% [markdown]
# ### Save Image

# %%
result = cv2.imwrite('Pencil Sketch Image.jpg', pencil_sketch_img)
if result == True:
    print('File saved successfully')
else:
    print('Error in saving file')
# Out:
# File saved successfully
